# %%
import pandas as pd

import matplotlib.pyplot as plt

from pathlib import Path

# %%
data_folder = Path("C:/Users/danie/Documents/py-data-analysis/gun-violence")
file_to_open = data_folder / "stage3.csv"

# %%
gun_violence = pd.read_csv(file_to_open)

# %%
gun_violence.plot.scatter(x='longitude', y='n_killed')

# %%
gun_violence.plot.scatter(x='latitude', y='n_killed')
